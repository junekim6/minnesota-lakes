# %%
import pandas as pd
from bs4 import BeautifulSoup
import time
import requests
import re
import glob
from pandas.errors import EmptyDataError

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Scrape "ice in" and "ice out" dates from Minnesota Department of Natural Resource.

# %%
# for lake_id in ids:
#     ice_in_url = f"https://maps1.dnr.state.mn.us/cgi-bin/climatology/ice_in_by_lake_as_csv.cgi?id={lake_id}"
#     response = requests.get(ice_in_url)
#     with open(f"data/ice_in/ice_in_{lake_id}.csv", "wb") as f:
#         f.write(response.content)
#     time.sleep(3)

# %%
# for lake_id in ids:
#     ice_out_url = f"https://maps1.dnr.state.mn.us/cgi-bin/climatology/ice_out_by_lake_as_csv.cgi?id={lake_id}"
#     response = requests.get(ice_out_url)
#     with open(f"data/ice_out/ice_out_{lake_id}.csv", "wb") as f:
#         f.write(response.content)
#     time.sleep(3)

# %% [markdown]
# ## Build dataframe of lake names and IDs from website HTMLL

# %%
with open('lake_id.txt', "r") as file:
    raw_ids = file.read().strip()

# %%
name_and_id = re.findall(r'">([^<]*)</option', raw_ids)
name_and_id = name_and_id[1:]

# %%
lakes = {}

for lake in name_and_id:
    lake_id = lake.split(" - ")[1]
    lake_name = lake.split(" - ")[0]
    lakes[lake_id] = lake_name

# %%
lake_profiles = pd.DataFrame([lakes]).transpose().reset_index()
lake_profiles.columns = ['lake_id', 'lake_name']

# %% [markdown]
# ## Analyze ice coverage data

# %% [markdown]
# #### Import and clean "ice in" dates

# %%
# Use glob to find all CSV files in the folder
ice_in = glob.glob("ice_in/*.csv")

# Create an empty DataFrame to store the concatenated data
df_in = pd.DataFrame()

# Loop over each CSV file and append it to the DataFrame
for f in ice_in:
    ice_in_data = pd.read_csv(f, header=2)
    id_from_file = f[-12:-4]
    ice_in_data["ID"] = id_from_file
    df_in = pd.concat([df_in, ice_in_data])

# %% [markdown]
# #### Import and clean "ice out" dates

# %%
# Use glob to find all CSV files in the folder
ice_out = glob.glob("ice_out/*.csv")

# Create an empty DataFrame to store the concatenated data
df_out = pd.DataFrame()

# Loop over each CSV file and appenfor f in ice_out:
for f in ice_out:
    try:
        ice_out_data = pd.read_csv(f, skiprows=2)
        id_from_file = f[-12:-4]
        ice_out_data["ID"] = id_from_file
        df_out = pd.concat([df_out, ice_out_data])
    except EmptyDataError:
        pass

# %% [markdown]
# #### Merge ice in and out data. Calculate ice days.

# %%
df_in.drop('Source', axis=1, inplace=True)
df_out.drop('Source', axis=1, inplace=True)

# %%
df = pd.merge(df_in, df_out, how="inner", on="ID")
df.columns = ['ice_in_date', 'lake_id', 'ice_out_date']
df = df[['lake_id', 'ice_in_date', 'ice_out_date']]

# %%
df.ice_in_date = pd.to_datetime(df.ice_in_date)
df.ice_out_date = pd.to_datetime(df.ice_out_date)

# %%
df['ice_days'] = df.ice_out_date - df.ice_in_date

# %%
df = df[(df.ice_days.dt.days > 0) & (df.ice_days.dt.days < 200)]

# %% [markdown]
# #### Merge lake id and lake name.

# %%
lake_profiles
# Out:
#       lake_id          lake_name
# 0    21024200              Aaron
# 1    18022500              Adney
# 2    69070100              Aerie
# 3    46003400              Amber
# 4    04003800           Andrusia
# ..        ...                ...
# 315  27003700              Wirth
# 316  04007900               Wolf
# 317  11020102  Woman (main lake)
# 318  10004100       Zumbra-Sunny
# 319  55000400             Zumbro
#
# [320 rows x 2 columns]

# %%
df = df.merge(lake_profiles, on="lake_id")

# %%
count = df.groupby('lake_id')['ice_days'].count().sort_values(ascending=False).reset_index()
count.columns = ['lake_id', 'measured_years']

# %%
count
# Out:
#       lake_id  measured_years
# 0    03038100             257
# 1    34007900             200
# 2    70007200             182
# 3    03038702             137
# 4    10005900             130
# ..        ...             ...
# 260  04007900               1
# 261  73003700               1
# 262  46005200               1
# 263  69006100               1
# 264  29016901               1
#
# [265 rows x 2 columns]

# %%
df_with_measured_years = df.merge(count, on="lake_id")
# df.drop(['measured_years_x', 'measured_years_y'], axis=1, inplace=True)

# %%
df = df_with_measured_years

# %%
df['year'] = df.ice_in_date.dt.year
df['ice_in_month'] = df.ice_in_date.dt.month
df['ice_out_month'] = df.ice_out_date.dt.month

# %%
df
# Out:
#        lake_id ice_in_date ice_out_date ice_days lake_name  measured_years  \
# 0     82001000  1992-11-14   1993-04-12 149 days  McDonald              35
# 1     82001000  1993-11-25   1994-04-01 127 days  McDonald              35
# 2     82001000  1994-11-25   1995-04-15 141 days  McDonald              35
# 3     82001000  1995-11-09   1996-04-19 162 days  McDonald              35
# 4     82001000  1996-11-12   1997-04-11 150 days  McDonald              35
# ...        ...         ...          ...      ...       ...             ...
# 4918  66003900  2007-12-01   2008-04-20 141 days   Mazaska               5
# 4919  66003900  2017-12-07   2018-04-30 144 days   Mazaska               5
# 4920  66003900  2017-12-07   2018-04-30 144 days   Mazaska               5
# 4921  66003900  2019-12-02   2020-03-30 119 days   Mazaska               5
# 4922  66003900  2021-12-06   2022-04-11 126 days   Mazaska               5
#
#       year  ice_in_month  ice_out_month
# 0     1992            11              4
# 1     1993            11              4
# 2     1994            11              4
# 3     1995            11              4
# 4     1996            11              4
# ...    ...           ...            ...
# 4918  2007            12              4
# 4919  2017            12              4
# 4920  2017            12              4
# 4921  2019            12              3
# 4922  2021            12              4
#
# [4923 rows x 9 columns]

# %%
df.groupby('year').count()
# Out:
#       lake_id  ice_in_date  ice_out_date  ice_days  lake_name  measured_years  \
# year
# 1899        2            2             2         2          2               2
# 1902        2            2             2         2          2               2
# 1903        2            2             2         2          2               2
# 1905        2            2             2         2          2               2
# 1906        2            2             2         2          2               2
# ...       ...          ...           ...       ...        ...             ...
# 2017      225          225           225       225        225             225
# 2018      222          222           222       222        222             222
# 2019      141          141           141       141        141             141
# 2020       83           83            83        83         83              83
# 2021      110          110           110       110        110             110
#
#       ice_in_month  ice_out_month
# year
# 1899             2              2
# 1902             2              2
# 1903             2              2
# 1905             2              2
# 1906             2              2
# ...            ...            ...
# 2017           225            225
# 2018           222            222
# 2019           141            141
# 2020            83             83
# 2021           110            110
#
# [119 rows x 8 columns]

# %%
yearly_df = pd.DataFrame(df.groupby('year')['ice_days'].mean())
yearly_df['num_lakes'] = df.groupby('year')['lake_id'].count()

# %%
yearly_df.reset_index(inplace=True)

# %%
min_samplesize = 10

yearly_min_sample_df =  yearly_df[yearly_df.num_lakes >= min_samplesize]

# %%
sample_years = ['1960', '1970', '1980', '1990', '2000', '2010', '2021']

# %%
sample_years_df = df[df.year.astype(str).isin(sample_years)]

# %%
sample_years_df
# Out:
#        lake_id ice_in_date ice_out_date ice_days     lake_name  \
# 8     82001000  2000-11-19   2001-04-15 147 days      McDonald
# 18    82001000  2010-11-23   2011-04-10 138 days      McDonald
# 58    66000800  1990-12-02   1991-04-01 120 days        Cannon
# 75    66000800  2021-12-06   2022-04-04 119 days        Cannon
# 83    05001300  2000-11-18   2001-04-20 153 days   Little Rock
# ...        ...         ...          ...      ...           ...
# 4844  04003800  2021-12-07   2022-05-07 151 days      Andrusia
# 4857  03008500  1980-12-02   1981-04-08 127 days  Bad Medicine
# 4867  03008500  1990-11-29   1991-04-20 142 days  Bad Medicine
# 4877  03008500  2000-12-05   2001-04-28 144 days  Bad Medicine
# 4922  66003900  2021-12-06   2022-04-11 126 days       Mazaska
#
#       measured_years  year  ice_in_month  ice_out_month
# 8                 35  2000            11              4
# 18                35  2010            11              4
# 58                21  1990            12              4
# 75                21  2021            12              4
# 83                59  2000            11              4
# ...              ...   ...           ...            ...
# 4844               2  2021            12              5
# 4857              58  1980            12              4
# 4867              58  1990            11              4
# 4877              58  2000            12              4
# 4922               5  2021            12              4
#
# [385 rows x 9 columns]

# %%
# %%R
#
# # install.packages('hrbrthemes')
# # install.packages('viridis')
#
# library(tidyverse)
# library(hrbrthemes)
# library(viridis)
# Out:
# R[write to console]: trying URL 'https://repo.miserver.it.umich.edu/cran/bin/macosx/contrib/4.2/viridis_0.6.2.tgz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 2998780 bytes (2.9 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.9 MB
# The downloaded binary packages are in
# 	/var/folders/_c/dcjy1m9109bd_sq8l8j8zsdr0000gn/T//Rtmptl7zG6/downloaded_packages

# %%
df.groupby('year').ice_days.mean().plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# #### Build Ridgeline plot of

# %%
df_40plus = df[df.measured_years>40]

# %%
df_40plus.lake_name.unique()
# Out:
# array(['Little Rock', 'Bemidji', 'Eighth Crow Wing', 'George',
#        'Farm Island', 'Wabana', 'Cedar', 'Green', 'Burntside', 'Mound',
#        'Portage', 'Kabekona', 'Washington', 'Lake of the Isles',
#        'Little McDonald', 'Long', 'Shagawa', 'Upper Prior', 'Detroit',
#        'Harriet', 'Devil Track', 'Floyd (south bay)', 'Paul',
#        'Minnetonka', 'Turtle', 'Wirth', 'Itasca', 'Long (Main Basin)',
#        'Bde Maka Ska', 'Pelican', 'Waconia', 'Bad Medicine'], dtype=object)

# %%
df_40plus.groupby(by="year")
